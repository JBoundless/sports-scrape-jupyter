# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests

url = "https://www.basketball-reference.com/leagues/NBA_2020_totals.html"
html = urlopen(url)

soup = BeautifulSoup(html)
soup.findAll('tr', limit=2)
# use getText()to extract the text we need into a list
headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]
# exclude the first column as we will not need the ranking order from Basketball Reference for the analysis
headers = headers[1:]
headers
rows = soup.findAll('tr')[1:]
player_stats = [[td.getText() for td in rows[i].findAll('td')]
            for i in range(len(rows))]
stats = pd.DataFrame(player_stats, columns = headers)
stats.head(50)
# Out:
#                       Player    Pos   Age    Tm     G    GS    MP    FG   FGA  \
# 0               Steven Adams      C    26   OKC    58    58  1564   262   443
# 1                Bam Adebayo     PF    22   MIA    65    65  2235   408   719
# 2          LaMarcus Aldridge      C    34   SAS    53    53  1754   391   793
# 3   Nickeil Alexander-Walker     SG    21   NOP    41     0   501    77   227
# 4              Grayson Allen     SG    24   MEM    30     0   498    79   176
# 5              Jarrett Allen      C    21   BRK    64    58  1647   267   413
# 6               Kadeem Allen     SG    27   NYK    10     0   117    19    44
# 7            Al-Farouq Aminu     PF    29   ORL    18     2   380    25    86
# 8            Justin Anderson     SF    26   BRK     3     0    17     1     6
# 9              Kyle Anderson     PF    26   MEM    59    20  1140   138   280
# 10             Ryan Anderson     PF    31   HOU     2     0    14     2     7
# 11     Giannis Antetokounmpo     PF    25   MIL    57    57  1763   623  1139
# 12      Kostas Antetokounmpo     PF    22   LAL     3     0     5     0     0
# 13    Thanasis Antetokounmpo     SF    27   MIL    18     2    93    19    36
# 14           Carmelo Anthony     PF    35   POR    50    50  1623   289   679
# 15                OG Anunoby     SF    22   TOR    63    62  1897   267   527
# 16          Ryan Arcidiacono     PG    25   CHI    58     4   930    90   220
# 17              Trevor Ariza     SF    34   TOT    53    21  1493   142   324
# 18              Trevor Ariza     SF    34   SAC    32     0   791    64   165
# 19              Trevor Ariza     SF    34   POR    21    21   702    78   159
# 20             D.J. Augustin     PG    32   ORL    49     6  1215   156   397
# 21             Deandre Ayton      C    21   PHO    30    25   996   255   465
# 22                      None   None  None  None  None  None  None  None  None
# 23              Dwayne Bacon     SG    24   CHO    39    11   687    85   244
# 24         Marvin Bagley III     PF    20   SAC    13     6   334    78   167
# 25                Lonzo Ball     PG    22   NOP    56    47  1817   259   628
# 26                  Mo Bamba      C    21   ORL    60     0   868   132   282
# 27                J.J. Barea     PG    35   DAL    26     4   391    74   179
# 28           Harrison Barnes     PF    27   SAC    64    64  2231   326   711
# 29                RJ Barrett     SG    19   NYK    56    55  1704   292   727
# 30               Will Barton     SF    29   DEN    58    58  1916   332   738
# 31          Keita Bates-Diop     SF    24   TOT    39     0   665    89   208
# 32          Keita Bates-Diop     SF    24   MIN    37     0   646    87   206
# 33          Keita Bates-Diop     SF    24   DEN     2     0    19     2     2
# 34             Nicolas Batum     SF    31   CHO    22     3   505    28    81
# 35               Aron Baynes      C    33   PHO    42    28   934   183   381
# 36             Kent Bazemore  SF-SG    30   TOT    64    21  1604   185   495
# 37             Kent Bazemore     SF    30   POR    43    21  1111   113   326
# 38             Kent Bazemore     SG    30   SAC    21     0   493    72   169
# 39             Darius Bazley     PF    19   OKC    53     8   909    88   230
# 40              Bradley Beal     SG    26   WAS    57    57  2053   593  1303
# 41             Malik Beasley     SG    23   TOT    55    14  1209   227   534
# 42             Malik Beasley     SG    23   DEN    41     0   746   117   301
# 43             Malik Beasley     SG    23   MIN    14    14   463   110   233
# 44           Marco Belinelli     SG    33   SAS    52     0   779   106   271
# 45               Jordan Bell   C-PF    25   TOT    29     0   256    35    67
# 46               Jordan Bell      C    25   MIN    27     0   235    32    60
# 47               Jordan Bell     PF    25   MEM     2     0    21     3     7
# 48           DeAndre' Bembry     SG    25   ATL    43     4   915   104   228
# 49             Dragan Bender     SF    22   TOT    16     3   286    41    92
#
#       FG%  ...    FT%   ORB   DRB   TRB   AST   STL   BLK   TOV    PF   PTS
# 0    .591  ...   .590   196   347   543   141    50    65    86   111   633
# 1    .567  ...   .690   165   518   683   333    78    85   185   164  1053
# 2    .493  ...   .827   103   289   392   129    36    87    74   128  1001
# 3    .339  ...   .607     8    72    80    74    11     7    40    46   211
# 4    .449  ...   .857     5    61    66    43     6     1    23    36   221
# 5    .646  ...   .620   195   410   605    85    37    85    72   144   681
# 6    .432  ...   .636     2     7     9    21     5     2     8     7    50
# 7    .291  ...   .655    24    63    87    21    18     8    17    27    78
# 8    .167  ...   .500     0     2     2     0     0     1     0     2     3
# 9    .493  ...   .652    54   203   257   132    46    31    55    85   335
# 10   .286  ...            0     7     7     2     1     0     1     1     5
# 11   .547  ...   .633   130   653   783   329    59    58   209   173  1690
# 12         ...            0     1     1     1     0     0     0     0     0
# 13   .528  ...   .467    11     8    19     9     6     2    11    13    45
# 14   .426  ...   .843    61   252   313    79    40    23    87   142   763
# 15   .507  ...   .686    74   267   341    99    88    42    75   155   675
# 16   .409  ...   .711    20    90   110    96    27     3    37    96   261
# 17   .438  ...   .838    34   212   246    91    69    15    56   111   423
# 18   .388  ...   .778    21   125   146    50    35     7    28    63   192
# 19   .491  ...   .872    13    87   100    41    34     8    28    48   231
# 20   .393  ...   .885    18    91   109   223    30     1    69    53   511
# 21   .548  ...   .769   123   237   360    57    22    51    71    97   570
# 22   None  ...   None  None  None  None  None  None  None  None  None  None
# 23   .348  ...   .660    15    85   100    52    23     2    37    52   224
# 24   .467  ...   .806    29    68    97    10     6    12    18    43   185
# 25   .412  ...   .567    63   285   348   392    80    30   172   110   695
# 26   .468  ...   .674    98   201   299    42    22    85    42   115   332
# 27   .413  ...   .944    10    38    48    99     4     2    35    25   194
# 28   .459  ...   .803    61   245   306   152    38    10    80    82   941
# 29   .402  ...   .614    50   229   279   143    55    17   124   122   803
# 30   .450  ...   .767    76   289   365   212    61    29    88   121   874
# 31   .428  ...   .710    21    91   112    30    17    21    14    38   258
# 32   .422  ...   .708    21    89   110    30    17    20    14    36   251
# 33  1.000  ...   .750     0     2     2     0     0     1     0     2     7
# 34   .346  ...   .900    25    75   100    66    17     8    22    41    79
# 35   .480  ...   .747    71   166   237    67    10    23    50   141   481
# 36   .374  ...   .768    24   253   277    85    70    39    85   182   557
# 37   .347  ...   .806    13   159   172    61    45    31    60   121   340
# 38   .426  ...   .729    11    94   105    24    25     8    25    61   217
# 39   .383  ...   .681    21   175   196    29    20    35    40    45   238
# 40   .455  ...   .842    52   190   242   347    71    23   194   126  1741
# 41   .425  ...   .818    18   130   148    75    40     8    57    77   615
# 42   .389  ...   .868     9    68    77    48    31     6    36    50   325
# 43   .472  ...   .750     9    62    71    27     9     2    21    27   290
# 44   .391  ...   .780     4    86    90    64    10     1    16    41   301
# 45   .522  ...   .613    30    51    81    16     3    10    21    19    93
# 46   .533  ...   .586    28    50    78    14     2    10    18    17    83
# 47   .429  ...  1.000     2     1     3     2     1     0     3     2    10
# 48   .456  ...   .542    34   118   152    81    55    19    60    84   249
# 49   .446  ...   .714    16    57    73    28     4     9    21    42   107
#
# [50 rows x 29 columns]
